# %%
import numpy
import sympy
import matplotlib.pyplot as plt
sympy.init_printing()

# %%
pi = sympy.pi
x = sympy.symbols('x')
limits = (-2*pi, 2*pi)
truncateSeriesAt = 5

f = x
Ff = sympy.fourier_series(f, limits=(x, *limits))
lambdaf = sympy.lambdify(x, f, modules=numpy)
lambdaFf = sympy.lambdify(x, Ff.truncate(truncateSeriesAt), modules=numpy)

X = numpy.linspace(float(limits[0]), float(limits[1]), 100)
yf = lambdaf(X)
yF = lambdaFf(X)
plt.plot(X, yf, 'k', label='Exact')
plt.plot(X, yF, 'r--', label='Fourier Series')

plt.legend(loc='best')
ax = plt.gca()
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")
ax.spines["left"].set_position(("data",0))
ax.spines["bottom"].set_position(("data",0))

plt.show()

# %%
pi = sympy.pi
x = sympy.symbols('x')
limits = (0, 1)
truncateSeriesAt = 5

f = x
Ff = sympy.fourier_series(f, limits=(x, *limits))
lambdaf = sympy.lambdify(x, f, modules=numpy)
lambdaFf = sympy.lambdify(x, Ff.truncate(truncateSeriesAt), modules=numpy)

X = numpy.linspace(float(limits[0]), float(limits[1]), 100)
yf = lambdaf(X)
yF = lambdaFf(X)
plt.plot(X, yf, 'k', label='Exact')
plt.plot(X, yF, 'r--', label='Fourier Series')

plt.legend(loc='best')
ax = plt.gca()
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")
ax.spines["left"].set_position(("data",0))
ax.spines["bottom"].set_position(("data",0))

plt.show()

# %% [markdown]
# I don't know why, but it doesn't work with nonsymetrical intervals.
